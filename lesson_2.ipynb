# %% [markdown]
# <a href="https://colab.research.google.com/github/AmazinglyUltra/amazinglyUltra.github.io/blob/main/lesson_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))
print(num1, "+" ,num2, "+" ,num3, "=",num1+num2+num3, sep=" ")
# Out:
# Enter number 1: 1
# Enter number 2: 2
# Enter number 3: 3
# 1 + 2 + 3 = 6

# %%
#2
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))
print("(",num1, "+" ,num2, "+" ,num3,")/3 = ",(num1+num2+num3)/3)
# Out:
# Enter number 1: 1
# Enter number 2: 2
# Enter number 3: 3
# ( 1 + 2 + 3 )/3 =  2.0

# %%
#3
b = int(input("Enter number b: "))
c = int(input("Enter number c: "))
a = int(input("Enter number a: "))
print("", "D", "=" ,b, "*" ,b, "-4" "*" ,a, "*" ,c," =", (b**2 -4*a*c))
# Out:
# Enter number b: 15
# Enter number c: 40
# Enter number a: 25
#  D = 15 * 15 -4* 25 * 40  = -3775

# %%
#4
num = int(input("Enter a number: "))
print(num," -5 =", (num-5))
print(num," * 5 =", (num*5))
# Out:
# Enter a number: 10
# 10  -5 = 5
# 10  * 5 = 50

# %%
#5
num = int(input("Enter a number: "))
print((str(num) + " ")*5)
# Out:
# Enter a number: 10
# 10 10 10 10 10

# %%
#6
num = int(input("Enter a number: "))
print((str(num) + " ") *num)
# Out:
# Enter a number: 5
# 5 5 5 5 5
